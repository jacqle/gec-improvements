# %%
from parse_coverage import load_df
import pandas as pd

# %%
gector_cat2_df = load_df("compare_gector_gold_cat2.txt")

# %%
gector_cat2_df
# Out:
#       category   TP  FP   FN       P       R    F0.5  total
# 0          ADJ    3   7   36  0.3000  0.0769  0.1899     39
# 1     ADJ:FORM    5   0    4  1.0000  0.5556  0.8621      9
# 2          ADV    7   5   30  0.5833  0.1892  0.4118     37
# 3         CONJ    1   0   14  1.0000  0.0667  0.2632     15
# 4        CONTR    0   0    1  1.0000  0.0000  0.0000      1
# 5          DET  204  81  194  0.7158  0.5126  0.6632    398
# 6        MORPH   28  15   60  0.6512  0.3182  0.5385     88
# 7         NOUN   16   4   98  0.8000  0.1404  0.4124    114
# 8    NOUN:INFL    6   3    0  0.6667  1.0000  0.7143      6
# 9     NOUN:NUM  134  25   69  0.8428  0.6601  0.7986    203
# 10   NOUN:POSS    6   4   15  0.6000  0.2857  0.4918     21
# 11        ORTH   15   7   24  0.6818  0.3846  0.5906     39
# 12       OTHER   20  30  340  0.4000  0.0556  0.1786    360
# 13        PART   21   9   16  0.7000  0.5676  0.6688     37
# 14        PREP  110  36  151  0.7534  0.4215  0.6509    261
# 15        PRON   13   7   47  0.6500  0.2167  0.4643     60
# 16       PUNCT  102  48  102  0.6800  0.5000  0.6343    204
# 17       SPELL   50   7   39  0.8772  0.5618  0.7886     89
# 18        VERB   35  17  131  0.6731  0.2108  0.4679    166
# 19   VERB:FORM   70  28   39  0.7143  0.6422  0.6986    109
# 20   VERB:INFL    1   0    1  1.0000  0.5000  0.8333      2
# 21    VERB:SVA   80  16   37  0.8333  0.6838  0.7984    117
# 22  VERB:TENSE   63  25  114  0.7159  0.3559  0.5955    177
# 23          WO    6   2   15  0.7500  0.2857  0.5660     21

# %%
gector_cat2_df.sort_values("F0.5", ascending=False)
# Out:
#       category   TP  FP   FN       P       R    F0.5  total
# 1     ADJ:FORM    5   0    4  1.0000  0.5556  0.8621      9
# 20   VERB:INFL    1   0    1  1.0000  0.5000  0.8333      2
# 9     NOUN:NUM  134  25   69  0.8428  0.6601  0.7986    203
# 21    VERB:SVA   80  16   37  0.8333  0.6838  0.7984    117
# 17       SPELL   50   7   39  0.8772  0.5618  0.7886     89
# 8    NOUN:INFL    6   3    0  0.6667  1.0000  0.7143      6
# 19   VERB:FORM   70  28   39  0.7143  0.6422  0.6986    109
# 13        PART   21   9   16  0.7000  0.5676  0.6688     37
# 5          DET  204  81  194  0.7158  0.5126  0.6632    398
# 14        PREP  110  36  151  0.7534  0.4215  0.6509    261
# 16       PUNCT  102  48  102  0.6800  0.5000  0.6343    204
# 22  VERB:TENSE   63  25  114  0.7159  0.3559  0.5955    177
# 11        ORTH   15   7   24  0.6818  0.3846  0.5906     39
# 23          WO    6   2   15  0.7500  0.2857  0.5660     21
# 6        MORPH   28  15   60  0.6512  0.3182  0.5385     88
# 10   NOUN:POSS    6   4   15  0.6000  0.2857  0.4918     21
# 18        VERB   35  17  131  0.6731  0.2108  0.4679    166
# 15        PRON   13   7   47  0.6500  0.2167  0.4643     60
# 7         NOUN   16   4   98  0.8000  0.1404  0.4124    114
# 2          ADV    7   5   30  0.5833  0.1892  0.4118     37
# 3         CONJ    1   0   14  1.0000  0.0667  0.2632     15
# 0          ADJ    3   7   36  0.3000  0.0769  0.1899     39
# 12       OTHER   20  30  340  0.4000  0.0556  0.1786    360
# 4        CONTR    0   0    1  1.0000  0.0000  0.0000      1

# %%
gector_cat2_df.sort_values("total", ascending=False)
# Out:
#       category   TP  FP   FN       P       R    F0.5  total
# 5          DET  204  81  194  0.7158  0.5126  0.6632    398
# 12       OTHER   20  30  340  0.4000  0.0556  0.1786    360
# 14        PREP  110  36  151  0.7534  0.4215  0.6509    261
# 16       PUNCT  102  48  102  0.6800  0.5000  0.6343    204
# 9     NOUN:NUM  134  25   69  0.8428  0.6601  0.7986    203
# 22  VERB:TENSE   63  25  114  0.7159  0.3559  0.5955    177
# 18        VERB   35  17  131  0.6731  0.2108  0.4679    166
# 21    VERB:SVA   80  16   37  0.8333  0.6838  0.7984    117
# 7         NOUN   16   4   98  0.8000  0.1404  0.4124    114
# 19   VERB:FORM   70  28   39  0.7143  0.6422  0.6986    109
# 17       SPELL   50   7   39  0.8772  0.5618  0.7886     89
# 6        MORPH   28  15   60  0.6512  0.3182  0.5385     88
# 15        PRON   13   7   47  0.6500  0.2167  0.4643     60
# 0          ADJ    3   7   36  0.3000  0.0769  0.1899     39
# 11        ORTH   15   7   24  0.6818  0.3846  0.5906     39
# 13        PART   21   9   16  0.7000  0.5676  0.6688     37
# 2          ADV    7   5   30  0.5833  0.1892  0.4118     37
# 10   NOUN:POSS    6   4   15  0.6000  0.2857  0.4918     21
# 23          WO    6   2   15  0.7500  0.2857  0.5660     21
# 3         CONJ    1   0   14  1.0000  0.0667  0.2632     15
# 1     ADJ:FORM    5   0    4  1.0000  0.5556  0.8621      9
# 8    NOUN:INFL    6   3    0  0.6667  1.0000  0.7143      6
# 20   VERB:INFL    1   0    1  1.0000  0.5000  0.8333      2
# 4        CONTR    0   0    1  1.0000  0.0000  0.0000      1

# %%
lt_cat2_df = load_df("compare_lt_gold_cat2.txt")

# %% [markdown]
# # plotting

# %%
df = pd.concat([lt_cat2_df[["category","F0.5"]].add_prefix("lt_"), gector_cat2_df[["category","F0.5"]].add_prefix("gector_")], axis=1)
df.drop("gector_category", axis=1, inplace=True)
df.rename(columns={"lt_category":"category", "lt_F0.5":"language_tool", "gector_F0.5": "gector"}, inplace=True)
df
# Out:
#       category  language_tool  gector
# 0          ADJ         0.3061  0.1899
# 1     ADJ:FORM         0.6667  0.8621
# 2          ADV         0.1250  0.4118
# 3         CONJ         0.0000  0.2632
# 4        CONTR         0.0000  0.0000
# 5          DET         0.1716  0.6632
# 6        MORPH         0.1813  0.5385
# 7         NOUN         0.0394  0.4124
# 8    NOUN:INFL         0.8929  0.7143
# 9     NOUN:NUM         0.1026  0.7986
# 10   NOUN:POSS         0.1515  0.4918
# 11        ORTH         0.2220  0.5906
# 12       OTHER         0.0610  0.1786
# 13        PART         0.0000  0.6688
# 14        PREP         0.1832  0.6509
# 15        PRON         0.0862  0.4643
# 16       PUNCT         0.2103  0.6343
# 17       SPELL         0.6677  0.7886
# 18        VERB         0.0613  0.4679
# 19   VERB:FORM         0.4857  0.6986
# 20   VERB:INFL         0.5000  0.8333
# 21    VERB:SVA         0.2740  0.7984
# 22  VERB:TENSE         0.0552  0.5955
# 23          WO         0.0000  0.5660

# %%
df=pd.melt(df,id_vars=['category'],var_name='tool', value_name='score')
df
# Out:
#       category           tool   score
# 0          ADJ  language_tool  0.3061
# 1     ADJ:FORM  language_tool  0.6667
# 2          ADV  language_tool  0.1250
# 3         CONJ  language_tool  0.0000
# 4        CONTR  language_tool  0.0000
# 5          DET  language_tool  0.1716
# 6        MORPH  language_tool  0.1813
# 7         NOUN  language_tool  0.0394
# 8    NOUN:INFL  language_tool  0.8929
# 9     NOUN:NUM  language_tool  0.1026
# 10   NOUN:POSS  language_tool  0.1515
# 11        ORTH  language_tool  0.2220
# 12       OTHER  language_tool  0.0610
# 13        PART  language_tool  0.0000
# 14        PREP  language_tool  0.1832
# 15        PRON  language_tool  0.0862
# 16       PUNCT  language_tool  0.2103
# 17       SPELL  language_tool  0.6677
# 18        VERB  language_tool  0.0613
# 19   VERB:FORM  language_tool  0.4857
# 20   VERB:INFL  language_tool  0.5000
# 21    VERB:SVA  language_tool  0.2740
# 22  VERB:TENSE  language_tool  0.0552
# 23          WO  language_tool  0.0000
# 24         ADJ         gector  0.1899
# 25    ADJ:FORM         gector  0.8621
# 26         ADV         gector  0.4118
# 27        CONJ         gector  0.2632
# 28       CONTR         gector  0.0000
# 29         DET         gector  0.6632
# 30       MORPH         gector  0.5385
# 31        NOUN         gector  0.4124
# 32   NOUN:INFL         gector  0.7143
# 33    NOUN:NUM         gector  0.7986
# 34   NOUN:POSS         gector  0.4918
# 35        ORTH         gector  0.5906
# 36       OTHER         gector  0.1786
# 37        PART         gector  0.6688
# 38        PREP         gector  0.6509
# 39        PRON         gector  0.4643
# 40       PUNCT         gector  0.6343
# 41       SPELL         gector  0.7886
# 42        VERB         gector  0.4679
# 43   VERB:FORM         gector  0.6986
# 44   VERB:INFL         gector  0.8333
# 45    VERB:SVA         gector  0.7984
# 46  VERB:TENSE         gector  0.5955
# 47          WO         gector  0.5660

# %%
fig, ax1 = plt.subplots(figsize=(15, 8))
plt.xticks(rotation=45)
sns.barplot(x='category', y='score', hue='tool', data=df, ax=ax1, ci="sd", palette="dark", alpha=.6)
sns.despine(fig)
